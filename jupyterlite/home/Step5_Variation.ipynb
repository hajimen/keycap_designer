# %%
# Boilerplate for JupyterLite 
import install_keycap_designer
from keycap_designer.jupyter import *

# %%
# There are several keycap variations in Junana profile.
# 2.25u:
Junana @ Specifier('225u') @ TopImage('mandrill.jpg')
# Out:
# Manuscript(profile=Profile('Junana'), specifier=Specifier('225u'), image=Image({Side.Top: ImageFile(path='mandrill.jpg')}))

# %%
# 1.5u:
Junana @ Specifier('15u') @ TopImage('mandrill.jpg')
# Out:
# Manuscript(profile=Profile('Junana'), specifier=Specifier('15u'), image=Image({Side.Top: ImageFile(path='mandrill.jpg')}))

# %%
# Convex 1u:
Junana @ Specifier('Convex 1u') @ TopImage('mandrill.jpg')
# Out:
# Manuscript(profile=Profile('Junana'), specifier=Specifier('Convex 1u'), image=Image({Side.Top: ImageFile(path='mandrill.jpg')}))

# %%
# Convex 1.5u:
Junana @ Specifier('Convex 15u') @ TopImage('mandrill.jpg')
# Out:
# Manuscript(profile=Profile('Junana'), specifier=Specifier('Convex 15u'), image=Image({Side.Top: ImageFile(path='mandrill.jpg')}))

# %%
# Convex 225u:
Junana @ Specifier('Convex 225u') @ TopImage('mandrill.jpg')
# Out:
# Manuscript(profile=Profile('Junana'), specifier=Specifier('Convex 225u'), image=Image({Side.Top: ImageFile(path='mandrill.jpg')}))

# %%
# ...and Homing 1u:
Junana @ Specifier('Homing 1u') @ TopImage('mandrill.jpg')
# Out:
# Manuscript(profile=Profile('Junana'), specifier=Specifier('Homing 1u'), image=Image({Side.Top: ImageFile(path='mandrill.jpg')}))
